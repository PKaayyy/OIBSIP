# %% [markdown]
# **Hi Myself , Pranav Kumbhar**
#
# **About project:**
#
#  Car price prediction using Python involves several key steps: collecting data from reliable sources, preprocessing it by cleaning and transforming features, and performing exploratory data analysis (EDA) to understand relationships within the data.

# %%
#Importing Libraries
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
#Reading CSV
df=pd.read_csv('/content/car data.csv')
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# ...

# %%
#Creating daTaframes
inputs=df.drop(['Car_Name','Owner','Selling_type'],axis='columns')
target=df.Selling_Price
target
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
#Encoding
from sklearn.preprocessing import LabelEncoder
Numerics=LabelEncoder()

# %%
#New encoded columns
inputs['Fuel_Type_n']=Numerics.fit_transform(inputs['Fuel_Type'])
inputs['Transmission_n']=Numerics.fit_transform(inputs['Transmission'])
inputs
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Transmission  \
# 0    2014           3.35           5.59       27000    Petrol       Manual
# 1    2013           4.75           9.54       43000    Diesel       Manual
# 2    2017           7.25           9.85        6900    Petrol       Manual
# 3    2011           2.85           4.15        5200    Petrol       Manual
# 4    2014           4.60           6.87       42450    Diesel       Manual
# ..    ...            ...            ...         ...       ...          ...
# 296  2016           9.50          11.60       33988    Diesel       Manual
# 297  2015           4.00           5.90       60000    Petrol       Manual
# 298  2009           3.35          11.00       87934    Petrol       Manual
# 299  2017          11.50          12.50        9000    Diesel       Manual
# 300  2016           5.30           5.90        5464    Petrol       Manual
#
#      Fuel_Type_n  Transmission_n
# 0              2               1
# ...

# %%
#Dropping string columns
inputs_n=inputs.drop(['Fuel_Type','Transmission','Selling_Price',],axis='columns')
inputs_n
# Out:
#      Year  Present_Price  Driven_kms  Fuel_Type_n  Transmission_n
# 0    2014           5.59       27000            2               1
# 1    2013           9.54       43000            1               1
# 2    2017           9.85        6900            2               1
# 3    2011           4.15        5200            2               1
# 4    2014           6.87       42450            1               1
# ..    ...            ...         ...          ...             ...
# 296  2016          11.60       33988            1               1
# 297  2015           5.90       60000            2               1
# 298  2009          11.00       87934            2               1
# 299  2017          12.50        9000            1               1
# 300  2016           5.90        5464            2               1
#
# [301 rows x 5 columns]

# %%
#Linear regression
model=linear_model.LinearRegression()

# %%
model.fit(inputs_n,target)
# Out:
# LinearRegression()

# %%
#PREDICTION
pred=model.predict([[2009,	11.00,	87934,	2,	1]])
print(pred)
# Out:
# [3.47009807]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# ...
